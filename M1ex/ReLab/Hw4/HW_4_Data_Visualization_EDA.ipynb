# %% [markdown]
# # Lab 4: Data Visualization and EDA
#
# #### CPE232 Data Models
#
# ---

# %% [markdown]
# 1. Load all Superstore datasets.
#
# *Note: The same datasets used in Lab 3*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Write your code here
superstore_order = pd.read_csv("Superstore/superstore_order.csv")
superstore_people = pd.read_csv("Superstore/superstore_people.csv")
superstore_return = pd.read_csv("Superstore/superstore_return.csv")

# %% [markdown]
# 2. Determine shape of each dataset (print out the results as well).

# %%
# Write your code here
print(superstore_order.shape)
print(superstore_people.shape)
print(superstore_return.shape)
# Out:
# (8880, 21)
# (4, 2)
# (296, 2)

# %% [markdown]
# 3. Show information of the dataset.

# %%
# Write your code here
superstore_order.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8880 entries, 0 to 8879
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         8880 non-null   int64
#  1   Order ID       8880 non-null   str
#  2   Order Date     8880 non-null   str
#  3   Ship Date      8880 non-null   str
#  4   Ship Mode      8880 non-null   str
#  5   Customer ID    8880 non-null   str
#  6   Customer Name  8880 non-null   str
#  7   Segment        8880 non-null   str
#  8   Country        8880 non-null   str
#  9   City           8880 non-null   str
#  10  State          8880 non-null   str
#  11  Postal Code    8880 non-null   int64
#  12  Region         8880 non-null   str
#  13  Product ID     8880 non-null   str
#  14  Category       8880 non-null   str
#  15  Sub-Category   8880 non-null   str
#  16  Product Name   8880 non-null   str
#  17  Sales          8880 non-null   float64
#  18  Quantity       8880 non-null   int64
#  19  Discount       8880 non-null   float64
#  20  Profit         8880 non-null   float64
# dtypes: float64(3), int64(3), str(15)
# memory usage: 1.4 MB

# %%
superstore_people.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Person  4 non-null      str
#  1   Region  4 non-null      str
# dtypes: str(2)
# memory usage: 196.0 bytes

# %%
superstore_return.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Returned  296 non-null    str
#  1   Order ID  296 non-null    str
# dtypes: str(2)
# memory usage: 4.8 KB

# %% [markdown]
# 4. Are there any missing values? If so, in which column?
#
# Ans: there are no missing values

# %%
superstore_order.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
superstore_people.isnull().sum()
# Out:
# Person    0
# Region    0
# dtype: int64

# %%
superstore_return.isnull().sum()
# Out:
# Returned    0
# Order ID    0
# dtype: int64

# %% [markdown]
# 5.
# - 5.1 List unique segments
# - 5.2 List unique segments and their corresponding count
# - 5.3 Create a pie chart to demonstrate unique segments and their count
# - 5.4 Briefly describe what could be interpreted from this pie chart
#
# *Note: please create additional cells to answer 5.2 - 5.3*

# %%
# Write your code here (5.1)
superstore_order["Segment"].unique()
# Out:
# <StringArray>
# ['Consumer', 'Corporate', 'Home Office']
# Length: 3, dtype: str

# %%
superstore_order["Segment"].value_counts()
# Out:
# Segment
# Consumer       4613
# Corporate      2673
# Home Office    1594
# Name: count, dtype: int64

# %%
seg_count = superstore_order["Segment"].value_counts().reset_index()
seg_count
# Out:
#        Segment  count
# 0     Consumer   4613
# 1    Corporate   2673
# 2  Home Office   1594

# %%
plt.pie(x=seg_count["count"],labels=seg_count["Segment"])
plt.show()

# %% [markdown]
# Answer for the question 5.4
#
# Ans: ________________________

# %% [markdown]
# 6.
# - 6.1 List unique states
# - 6.2 List top-10 unique states and their corresponding count
# - 6.3 Create a bar chart (vertical) to demonstrate the count of top-10 unique states
# - 6.4 Based on 6.2, also include the total sales of these states (show your result as a dataframe)
# - 6.5 Using the result from 6.4, if you were the owner of this superstore, what information could be interpreted from this result?
#
# *Note: please create additional cells to answer 6.2 - 6.4*

# %%
# Write your code here (6.1)
superstore_order["State"].unique()
# Out:
# <StringArray>
# [            'Kentucky',           'California',              'Florida',
#        'North Carolina',           'Washington',                'Texas',
#             'Wisconsin',                 'Utah',             'Nebraska',
#          'Pennsylvania',             'Illinois',            'Minnesota',
#              'Michigan',             'Delaware',              'Indiana',
#              'New York',              'Arizona',             'Virginia',
#             'Tennessee',              'Alabama',       'South Carolina',
#                'Oregon',             'Colorado',                 'Iowa',
#                  'Ohio',             'Missouri',             'Oklahoma',
#            'New Mexico',            'Louisiana',          'Connecticut',
#            'New Jersey',        'Massachusetts',              'Georgia',
#                'Nevada',         'Rhode Island',          'Mississippi',
#              'Arkansas',              'Montana',        'New Hampshire',
#              'Maryland', 'District of Columbia',               'Kansas',
#               'Vermont',                'Maine',         'South Dakota',
#                 'Idaho',         'North Dakota',              'Wyoming',
#         'West Virginia']
# Length: 49, dtype: str

# %%
top10 = superstore_order["State"].value_counts()[:10]
top10
# Out:
# State
# California        1754
# New York          1001
# Texas              860
# Pennsylvania       531
# Washington         452
# Illinois           427
# Ohio               396
# Florida            339
# Michigan           230
# North Carolina     229
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.bar(x=top10.index,height=superstore_order["State"].value_counts()[:10])
plt.show()

# %%
superstore_order
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  08/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688  12/06/2016  16/06/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 8875    8876  US-2016-141264  13/08/2016  19/08/2016  Standard Class
# 8876    8877  US-2016-141264  13/08/2016  19/08/2016  Standard Class
# 8877    8878  CA-2017-126928  17/09/2017  23/09/2017  Standard Class
# 8878    8879  CA-2017-126928  17/09/2017  23/09/2017  Standard Class
# 8879    8880  US-2015-107944  23/03/2015  25/03/2015     First Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# 1       CG-12520      Claire Gute   Consumer  United States        Henderson
# 2       DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean ODonnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean ODonnell   Consumer  United States  Fort Lauderdale
# ...          ...              ...        ...            ...              ...
# 8875    CT-11995     Carol Triggs   Consumer  United States           Irving
# 8876    CT-11995     Carol Triggs   Consumer  United States           Irving
# 8877    GZ-14470    Gary Zandusky   Consumer  United States       Morristown
# 8878    GZ-14470    Gary Zandusky   Consumer  United States       Morristown
# 8879    AM-10360   Alice McCarthy  Corporate  United States      Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 0     ...       42420    South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420    South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036     West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311    South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311    South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...      ...              ...              ...          ...
# 8875  ...       75061  Central  OFF-SU-10003505  Office Supplies     Supplies
# 8876  ...       75061  Central  OFF-AP-10002534  Office Supplies   Appliances
# 8877  ...        7960     East  TEC-MA-10004626       Technology     Machines
# 8878  ...        7960     East  OFF-ST-10000615  Office Supplies      Storage
# 8879  ...       90008     West  OFF-PA-10000659  Office Supplies        Paper
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs ...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                         Eldon Fold N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 8875                     Premier Electric Letter Opener  185.3760         2
# 8876  3.6 Cubic Foot Counter Height Office Refrigerator   58.9240         1
# 8877  Lexmark 20R1285 X6650 Wireless All-in-One Printer  480.0000         4
# 8878  SimpliFile Personal File Black Granite 15w x 6...   34.0500         3
# 8879  TOPS Carbonless Receipt Book Four 2-3/4 x 7-1/...  192.7200        11
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 8875      0.20  -34.7580
# 8876      0.80 -153.2024
# 8877      0.00  225.6000
# 8878      0.00    9.5340
# 8879      0.00   92.5056
#
# [8880 rows x 21 columns]

# %%
salesDf = superstore_order[["State","Sales"]]
salesByState = salesDf.groupby("State").agg({"Sales":"sum"})
salesByState
# Out:
#                             Sales
# State
# Alabama                19272.4900
# Arizona                32990.1060
# Arkansas                9427.4400
# California            399195.4555
# Colorado               31080.8060
# Connecticut            12829.0570
# Delaware               26379.4290
# District of Columbia    2865.0200
# Florida                84083.0880
# Georgia                47940.1900
# Idaho                   4257.8360
# Illinois               71456.1780
# Indiana                48231.1400
# Iowa                    4315.0400
# Kansas                  2914.3100
# Kentucky               32418.5200
# Louisiana               7589.5400
# Maine                    653.4100
# Maryland               23145.6830
# Massachusetts          25217.6840
# Michigan               62147.6960
# Minnesota              29254.1000
# Mississippi            10394.2200
# Missouri               14074.6400
# Montana                 5589.3520
# Nebraska                7025.0200
# Nevada                 15478.1460
# New Hampshire           6947.8840
# New Jersey             33746.7120
# New Mexico              4486.0880
# New York              274866.8190
# North Carolina         49962.1580
# North Dakota             919.9100
# Ohio                   67924.2140
# Oklahoma               17563.2000
# Oregon                 15545.0310
# Pennsylvania          103852.5210
# Rhode Island           22468.1660
# South Carolina          8481.7100
# South Dakota            1290.0600
# Tennessee              27174.9150
# Texas                 147855.0282
# Utah                   11220.0560
# Vermont                 2214.9800
# Virginia               64632.5200
# Washington            124497.7780
# West Virginia            536.4800
# Wisconsin              27676.9000
# Wyoming                 1603.1360

# %% [markdown]
# Answer for the question 6.5
#
# Ans: ________________________

# %% [markdown]
# 7.
# - 7.1 List unique categories
# - 7.2 Create a bar chart (horizontal) to demonstrate the proportion of these categories
# - 7.3 Compute the ratio of these categories in percentage and print the results
#
# *Note: please create additional cells to answer 7.2 - 7.3*

# %%
# Write your code here (7.1)
superstore_order["Category"].unique()
# Out:
# <StringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str

# %%
nuniqueCat = superstore_order["Category"].value_counts().reset_index()
nuniqueCat
# Out:
#           Category  count
# 0  Office Supplies   5360
# 1        Furniture   1880
# 2       Technology   1640

# %%
plt.barh(y=nuniqueCat["Category"],width=nuniqueCat["count"])
# Out:
# <BarContainer object of 3 artists>

# %%
sumCat = nuniqueCat["count"].sum()
nuniqueCat["Percentage"] = nuniqueCat["count"]/sumCat
nuniqueCat
# Out:
#           Category  count  Percentage
# 0  Office Supplies   5360    0.603604
# 1        Furniture   1880    0.211712
# 2       Technology   1640    0.184685

# %% [markdown]
# 8. Update the type of all columns that contain dates to *datetime* and show information after an update.

# %%
# write your code here
superstore_order['Order Date'] = pd.to_datetime(superstore_order['Order Date'], format="%d/%m/%Y")
superstore_order['Ship Date'] = pd.to_datetime(superstore_order['Ship Date'], format="%d/%m/%Y")

# %% [markdown]
# 9. Create a new column "Processing time day" to show number of days taken to ship an order and show your result in a dataframe format.
#
# *Hint: The duration starts as soon as the item has been ordered and ends once the order has successfully shipped.*

# %%
superstore_order["Processing time day"] = (superstore_order["Ship Date"] - superstore_order["Order Date"]).dt.days
superstore_order
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 8875    8876  US-2016-141264 2016-08-13 2016-08-19  Standard Class
# 8876    8877  US-2016-141264 2016-08-13 2016-08-19  Standard Class
# 8877    8878  CA-2017-126928 2017-09-17 2017-09-23  Standard Class
# 8878    8879  CA-2017-126928 2017-09-17 2017-09-23  Standard Class
# 8879    8880  US-2015-107944 2015-03-23 2015-03-25     First Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# 1       CG-12520      Claire Gute   Consumer  United States        Henderson
# 2       DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean ODonnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean ODonnell   Consumer  United States  Fort Lauderdale
# ...          ...              ...        ...            ...              ...
# 8875    CT-11995     Carol Triggs   Consumer  United States           Irving
# 8876    CT-11995     Carol Triggs   Consumer  United States           Irving
# 8877    GZ-14470    Gary Zandusky   Consumer  United States       Morristown
# 8878    GZ-14470    Gary Zandusky   Consumer  United States       Morristown
# 8879    AM-10360   Alice McCarthy  Corporate  United States      Los Angeles
#
#       ...   Region       Product ID         Category Sub-Category  \
# 0     ...    South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...    South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...    South  FUR-TA-10000577        Furniture       Tables
# 4     ...    South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...      ...              ...              ...          ...
# 8875  ...  Central  OFF-SU-10003505  Office Supplies     Supplies
# 8876  ...  Central  OFF-AP-10002534  Office Supplies   Appliances
# 8877  ...     East  TEC-MA-10004626       Technology     Machines
# 8878  ...     East  OFF-ST-10000615  Office Supplies      Storage
# 8879  ...     West  OFF-PA-10000659  Office Supplies        Paper
#
#                                            Product Name     Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600        2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs ...  731.9400        3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                         Eldon Fold N Roll Cart System   22.3680        2
# ...                                                 ...       ...      ...
# 8875                     Premier Electric Letter Opener  185.3760        2
# 8876  3.6 Cubic Foot Counter Height Office Refrigerator   58.9240        1
# 8877  Lexmark 20R1285 X6650 Wireless All-in-One Printer  480.0000        4
# 8878  SimpliFile Personal File Black Granite 15w x 6...   34.0500        3
# 8879  TOPS Carbonless Receipt Book Four 2-3/4 x 7-1/...  192.7200       11
#
#       Discount    Profit  Processing time day
# 0         0.00   41.9136                    3
# 1         0.00  219.5820                    3
# 2         0.00    6.8714                    4
# 3         0.45 -383.0310                    7
# 4         0.20    2.5164                    7
# ...        ...       ...                  ...
# 8875      0.20  -34.7580                    6
# 8876      0.80 -153.2024                    6
# 8877      0.00  225.6000                    6
# 8878      0.00    9.5340                    6
# 8879      0.00   92.5056                    2
#
# [8880 rows x 22 columns]

# %% [markdown]
# 10. Based on the result in 9.
# - 10.1 How many orders are there that take more than 5 days to process?
# - 10.2 Show the top 5 rows (expected output should contain these columns: Order ID, Order Date, Ship Date, Processing time day, Quantity)
# - 10.3 Plot the histogram based on the column Quantity
#
# *Note: please create additional cells to answer 10.2 - 10.3*

# %%
superstore_order[superstore_order["Processing time day"]>5].shape[0]
# Out:
# 1656

# %%
superstore_order[superstore_order["Processing time day"]>5].head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4        5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 16      17  CA-2014-105893 2014-11-11 2014-11-18  Standard Class    PK-19075
# 53      54  CA-2016-105816 2016-12-11 2016-12-17  Standard Class    JM-15265
# 54      55  CA-2016-105816 2016-12-11 2016-12-17  Standard Class    JM-15265
#
#      Customer Name    Segment        Country             City  ...   Region  \
# 3    Sean ODonnell   Consumer  United States  Fort Lauderdale  ...    South
# 4    Sean ODonnell   Consumer  United States  Fort Lauderdale  ...    South
# 16       Pete Kriz   Consumer  United States          Madison  ...  Central
# 53  Janet Molinari  Corporate  United States    New York City  ...     East
# 54  Janet Molinari  Corporate  United States    New York City  ...     East
#
#          Product ID         Category Sub-Category  \
# 3   FUR-TA-10000577        Furniture       Tables
# 4   OFF-ST-10000760  Office Supplies      Storage
# 16  OFF-ST-10004186  Office Supplies      Storage
# 53  OFF-FA-10000304  Office Supplies    Fasteners
# 54  TEC-PH-10002447       Technology       Phones
#
#                                          Product Name      Sales Quantity  \
# 3       Bretford CR4500 Series Slim Rectangular Table   957.5775        5
# 4                       Eldon Fold N Roll Cart System    22.3680        2
# 16  Stur-D-Stor Shelving Vertical 5-Shelf: 72H x 3...   665.8800        6
# 53                                 Advantus Push Pins    15.2600        7
# 54                   AT&T CL83451 4-Handset Telephone  1029.9500        5
#
#     Discount    Profit  Processing time day
# 3       0.45 -383.0310                    7
# 4       0.20    2.5164                    7
# 16      0.00   13.3176                    7
# 53      0.00    6.2566                    6
# 54      0.00  298.6855                    6
#
# [5 rows x 22 columns]

# %%
plt.hist(x=superstore_order[superstore_order["Processing time day"]>5]["Quantity"],bins=10)
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 11. Total sales compare across different regions
#
# - 11.1 Create a bar chart to visualize.

# %%
# Write your code here (11.1)
region_sales = superstore_order.groupby("Region").agg({"Sales":"sum"})
region_sales
# Out:
#                Sales
# Region
# Central  434723.2222
# East     603648.0590
# South    361376.7910
# West     645943.7905

# %%
plt.bar(x=region_sales.index,height=region_sales["Sales"])
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
plt.barh(y=region_sales.index,width=region_sales["Sales"])
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# - 11.2 How do total sales compare across different regions? Explain in as much detail as possible.
#
#   Ans:

# %% [markdown]
# 12.Which states have the highest number of returns? Use a horizontal bar chart.
#
# Ans:

# %%
# Write your code here (12)
returned = pd.merge(left=superstore_order,right=superstore_return,how="inner")
returned["State"].value_counts()[:1]
# Out:
# State
# California    298
# Name: count, dtype: int64

# %% [markdown]
# 13. What is the correlation between numerical variables in the superstore_order dataset? Use a heatmap
# *Hint: Use seaborn to create a heatmap :)*

# %%
numerical_row
# Out:
#          Sales    Profit  Discount  Quantity
# 0     261.9600   41.9136      0.00         2
# 1     731.9400  219.5820      0.00         3
# 2      14.6200    6.8714      0.00         2
# 3     957.5775 -383.0310      0.45         5
# 4      22.3680    2.5164      0.20         2
# ...        ...       ...       ...       ...
# 8875  185.3760  -34.7580      0.20         2
# 8876   58.9240 -153.2024      0.80         1
# 8877  480.0000  225.6000      0.00         4
# 8878   34.0500    9.5340      0.00         3
# 8879  192.7200   92.5056      0.00        11
#
# [8880 rows x 4 columns]

# %%
# Write your code here (13)
numerical_row = superstore_order[['Sales', 'Profit', 'Discount', 'Quantity']]
numerical_row_cor = numerical_row.corr()
plt.imshow(numerical_row_cor, cmap='hot',interpolation='nearest')
plt.colorbar(label='Value')

# %% [markdown]
# 14. Create a USA State-Level Choropleth Map to visualize total sales per state.
#
# *   The darkest color represents the highest total sales.
# *   The lightest color represents the lowest total sales.
# *   Use a continuous gradient scale (e.g., dark blue to light blue, dark red to light red, or any custom gradient of your choice).
#
# *Hint: Use plotly.express*

# %%
# Write your code here (14)

# %% [markdown]
#   14.2 Answer the following questions:
# 1.   Which state has the highest total sales?
# 2.   How do sales anomalies affect the gradient color shading on the map?
# 3.   If you change the color scale, does it impact readability? Why or why not?

# %% [markdown]
# Ans:
#
#
# 1.
# 2.
# 3.

# %% [markdown]
# 15. Create a box plot to compare the different shipping modes based on total profit.

# %%
#Write your code here (15)
# ship_profit = superstore_order.groupby("Ship Mode").agg({"Sales":"sum"})
superstore_order.boxplot(column="Sales", by="Ship Mode")
plt.yscale("log")
plt.show()

# %% [markdown]
# 15.2 Which shipping mode has the highest median profit?
#
# Ans:

# %% [markdown]
# [BONUS 20 pts] Determine the percentage of customers who:
# - B1)returned the product once
# - B2) returned the product at least once
# - B3) never returned the product
# - Finally, Plot a comparison of B2 and B3
#
# *Note: please create additional cells to answer the above points*

# %%
# Write your code here

customer_Order = superstore_order[["Order ID","Customer ID"]]
customer_Order
returned_c_o = pd.merge(customer_Order,superstore_return,how="outer")
returned_c_o["Returned"] = returned_c_o["Returned"].fillna("No")
returned_c_o["isRT"] = returned_c_o["Returned"].map({"Yes": 1, "No": 0})
rt_times = returned_c_o.groupby("Customer ID").agg({"isRT":"sum"})
rt_times
# Out:
#              isRT
# Customer ID
# AA-10315        0
# AA-10375        0
# AA-10480        0
# AA-10645        1
# AB-10015        0
# ...           ...
# XP-21865        3
# YC-21895        1
# YS-21880        0
# ZC-21910        4
# ZD-21925        3
#
# [789 rows x 1 columns]

# %%
customer_cnt = len(rt_times)
once_rt = len(rt_times[rt_times["isRT"]==1])
b1 = once_rt/customer_cnt

# %%
non0_rt = len(rt_times[rt_times["isRT"]>0])
non0_rt
# Out:
# 222

# %%
z_rt = len(rt_times[rt_times["isRT"]==0])
z_rt
# Out:
# 567

# %%
plt.bar(x=["zeroRtCustomer","non0_rtCustomer"],height=[z_rt,non0_rt])
# Out:
# <BarContainer object of 2 artists>
